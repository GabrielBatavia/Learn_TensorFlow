# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielBatavia/Learn_TensorFlow/blob/main/02_neural_network_classification_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![02-tensorflow-playground-replication-exercise.png](data:image/png;base64,...)

# %% [markdown]
# Replicate the model pictured in the TensorFlow Playground diagram below using TensorFlow code. Compile it using the Adam optimizer, binary crossentropy loss and accuracy metric. Once it's compiled check a summary of the model.

# %%
# first of all, make the dataset
from sklearn.datasets import make_circles

# make 300 examples
n_samples = 300

# create circles
x, y = make_circles(n_samples,
                    noise=0.05,
                    random_state=42)

# %%
# Check out the features and labels
x[:5] , y[:5]
# Out:
# (array([[-0.42321019,  0.66412193],
#         [ 0.25358753, -0.78672959],
#         [ 0.72687402,  0.06521579],
#         [ 0.8816257 ,  0.41698355],
#         [-0.75340209, -0.26995691]]),
#  array([1, 1, 1, 0, 1]))

# %%
# visualize for understand the data

import pandas as pd
circles = pd.DataFrame({"x0":x[:, 0], "x1":x[:, 1], "label":y})
circles
# Out:
#            x0        x1  label
# 0   -0.423210  0.664122      1
# 1    0.253588 -0.786730      1
# 2    0.726874  0.065216      1
# 3    0.881626  0.416984      0
# 4   -0.753402 -0.269957      1
# ..        ...       ...    ...
# 295  0.024081  0.830758      1
# 296 -0.921683  0.219879      0
# 297 -0.291607 -0.931515      0
# 298  0.170886 -0.763740      1
# 299 -0.384855 -0.898135      0
#
# [300 rows x 3 columns]

# %%
# visualize with plot

import matplotlib.pyplot as plt

plt.scatter(x[:, 0], x[:, 1], c=y, cmap=plt.cm.RdYlBu);
